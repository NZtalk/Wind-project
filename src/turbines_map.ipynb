# %%
import pandas as pd
from sqlalchemy import *
from create_ref_mariadb import mariadb_connection
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import folium
import numpy as np
from plotly import graph_objects as go
from plotly.subplots import make_subplots
import folium
import branca
import os

# %%
#get data from ref
eng = mariadb_connection()
df = pd.read_sql(
    """SELECT p.windturbine_id, windspeed, power, windfarm_id,latitude,longitude
        FROM mariadb_itw.windturbines as wt inner join mariadb_itw.powercurves as p
        on p.windturbine_id = wt.windturbine_id ;""",
    con=eng
    )

# %%
if not os.path.exists('figures'):
   os.makedirs('figures')

# %%
figs = {} # Create an empty figure to which we will add all the plotly figures
turbines_list=[] #Create an empty list to which we will append all the cities
html_list=[] #Create an empty list to which we will append all the exported html files
turbines = df['windturbine_id'].unique() # Get the list of city names
turbines=turbines[0:10]
for i, turb in enumerate(turbines, start = 0):
    turbines_list.append(turb)
    html_list.append('fig'+str(i)+'.html')
    df_turb = df[df['windturbine_id']==turb]

    fig=make_subplots(specs=[[{"secondary_y":True}]])

    fig.add_trace(                           #Add a bar chart to the figure
            go.Bar(
            x=df_turb['windspeed'],
            y=df_turb['power']                    
            ),
            secondary_y=False)               #The bar chart uses the primary y-axis (left)

    fig.update_layout(hoverlabel_bgcolor='#DAEEED',  #Change the background color of the tooltip to light gray
                title_text="Powercurves for turbine_id: "+ turb, #Add a chart title
                title_font_family="Times New Roman",
                title_font_size = 20,
                title_font_color="darkblue", #Specify font color of the title
                title_x=0.5, #Specify the title position
                
                yaxis_title='power',
                xaxis_title="windspeed")


    
    figs['fig'+str(i)] = fig
    fig.write_html('fig'+str(i)+".html")

df1=pd.DataFrame(turbines_list,columns =['windturbine_id'])
df2=pd.DataFrame(html_list,columns =['html_file'])
df3=pd.concat([df1, df2], axis=1)
df_geo=df[['windfarm_id','windturbine_id','latitude','longitude']].drop_duplicates('windturbine_id')
df_final=df3.merge(df_geo, on='windturbine_id', how='left')
df_final
# Out:
#                          windturbine_id  html_file
# 0  1ec6d7ce-93f7-6ef8-abda-53533bbf8f7e  fig0.html  \
# 1  1ec6d7ce-93fa-6edc-a613-53533bbf8f7e  fig1.html
# 2  1ec6d7ce-93fd-6272-a3af-53533bbf8f7e  fig2.html
# 3  1ec6d7ce-93ff-639c-9afd-53533bbf8f7e  fig3.html
# 4  1ec6d7ce-9401-646c-b141-53533bbf8f7e  fig4.html
# 5  1ec6d7ce-9403-651e-866d-53533bbf8f7e  fig5.html
# 6  1ec6d7ce-9406-6688-98b1-53533bbf8f7e  fig6.html
# 7  1ec6d7ce-9408-6802-b9c6-53533bbf8f7e  fig7.html
# 8  1ec6d7ce-940a-6b02-aa72-53533bbf8f7e  fig8.html
# 9  1ec6d7ce-940c-6b96-a952-53533bbf8f7e  fig9.html
#
#                             windfarm_id  latitude  longitude
# 0  1ec6d7a1-4b96-67a4-9358-df2d2b033685   48.7136    4.44707
# 1  1ec6d7a1-4b96-67a4-9358-df2d2b033685   48.7169    4.45140
# 2  1ec6d7a1-4b96-67a4-9358-df2d2b033685   48.7193    4.45693
# 3  1ec6d7a1-4b96-67a4-9358-df2d2b033685   48.7212    4.46288
# 4  1ec6d7a1-4b96-67a4-9358-df2d2b033685   48.7225    4.46990
# 5  1ec6d7a1-4b96-67a4-9358-df2d2b033685   48.7243    4.47628
# 6  1ec6d7a1-4b96-67a4-9358-df2d2b033685   48.7262    4.48286
# 7  1ec6d7a1-4b96-67a4-9358-df2d2b033685   48.7300    4.48715
# 8  1ec6d7a1-4bf4-6ab6-a587-df2d2b033685   48.6630    4.13350
# 9  1ec6d7a1-4bf4-6ab6-a587-df2d2b033685   48.6646    4.13952

# %%
location = df_final['latitude'].mean(), df_final['longitude'].mean()
m = folium.Map(location=location,zoom_start=4)

for i in range(0,len(df_final)):
    html="""
    <iframe src=\"""" + df_final['html_file'][i] + """\" width="850" height="400"  frameborder="0">    
    """
    
    popup = folium.Popup(folium.Html(html, script=True))
    folium.Marker([df_final['latitude'].iloc[i],df_final['longitude'].iloc[i]],
                  popup=popup,icon=folium.Icon( icon='home', prefix='fa')).add_to(m)
    
m.save("index.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdcbeed291c652a417ea6777de5fb46a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdcbeed291c652a417ea6777de5fb46a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdcbeed291c652a417ea6777de5fb46a = L.map(
#                 &quot;map_bdcbeed291c652a417ea6777de5fb46a&quot;,
#                 {
#                     center: [48.71016, 4.400748999999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5965926ba5e0f4f7d168b2a24f18d36 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bdcbeed291c652a417ea6777de5fb46a);
#
#
#             var marker_27be4e03d29a43b13ab1955b1dc71785 = L.marker(
#                 [48.7136, 4.44707],
#                 {}
#             ).addTo(map_bdcbeed291c652a417ea6777de5fb46a);
#
#
#             var icon_254f39395df15a32b5b65a22a2761670 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_27be4e03d29a43b13ab1955b1dc71785.setIcon(icon_254f39395df15a32b5b65a22a2761670);
#
#
#         var popup_3cffe95dfdcfe5f0a44fc29fcc8fe7ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0695f85bb285e3ebc4387da30f1c4213 = $(`&lt;div id=&quot;html_0695f85bb285e3ebc4387da30f1c4213&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;iframe src=&quot;fig0.html&quot; width=&quot;850&quot; height=&quot;400&quot;  frameborder=&quot;0&quot;&gt;         &lt;/div&gt;`)[0];
#                 popup_3cffe95dfdcfe5f0a44fc29fcc8fe7ea.setContent(html_0695f85bb285e3ebc4387da30f1c4213);
#
#
#
#         marker_27be4e03d29a43b13ab1955b1dc71785.bindPopup(popup_3cffe95dfdcfe5f0a44fc29fcc8fe7ea)
#         ;
#
#
#
#
#             var marker_1ca0d035d001b2ff148ca21261ac0e65 = L.marker(
#                 [48.7169, 4.4514],
#                 {}
#             ).addTo(map_bdcbeed291c652a417ea6777de5fb46a);
#
#
#             var icon_5cc69b4ac38b559a65e56f36bdeb8ad4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_1ca0d035d001b2ff148ca21261ac0e65.setIcon(icon_5cc69b4ac38b559a65e56f36bdeb8ad4);
#
#
#         var popup_96409a7a9f52698a3e57bb1a708898cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75376c29b5a29e554fc001fd9cb1d33b = $(`&lt;div id=&quot;html_75376c29b5a29e554fc001fd9cb1d33b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;iframe src=&quot;fig1.html&quot; width=&quot;850&quot; height=&quot;400&quot;  frameborder=&quot;0&quot;&gt;         &lt;/div&gt;`)[0];
#                 popup_96409a7a9f52698a3e57bb1a708898cb.setContent(html_75376c29b5a29e554fc001fd9cb1d33b);
#
#
#
#         marker_1ca0d035d001b2ff148ca21261ac0e65.bindPopup(popup_96409a7a9f52698a3e57bb1a708898cb)
#         ;
#
#
#
#
#             var marker_aabf129b3c7bf3021c0c2da91be6e217 = L.marker(
#                 [48.7193, 4.45693],
#                 {}
#             ).addTo(map_bdcbeed291c652a417ea6777de5fb46a);
#
#
#             var icon_e2fd0991007c32e59205b6a0a8b4c99c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_aabf129b3c7bf3021c0c2da91be6e217.setIcon(icon_e2fd0991007c32e59205b6a0a8b4c99c);
#
#
#         var popup_76500d119856af1a7dd5f50911dbaf85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff01fa65d811961d6418a62c29be95e7 = $(`&lt;div id=&quot;html_ff01fa65d811961d6418a62c29be95e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;iframe src=&quot;fig2.html&quot; width=&quot;850&quot; height=&quot;400&quot;  frameborder=&quot;0&quot;&gt;         &lt;/div&gt;`)[0];
#                 popup_76500d119856af1a7dd5f50911dbaf85.setContent(html_ff01fa65d811961d6418a62c29be95e7);
#
#
#
#         marker_aabf129b3c7bf3021c0c2da91be6e217.bindPopup(popup_76500d119856af1a7dd5f50911dbaf85)
#         ;
#
#
#
#
#             var marker_84693d1a10970816f66ef49df42432b8 = L.marker(
